# %%
import pandas as pd

df = pd.read_parquet("../samples.parquet")

print("Cantidad total de imágenes:", len(df))
df.head()
# Out:
# Cantidad total de imágenes: 16323
#                       image_path     label subset format  width  height  \
# 0  data\Bleeding\DICOM\10002.dcm  Bleeding  train  DICOM    NaN     NaN
# 1  data\Bleeding\DICOM\10033.dcm  Bleeding  train  DICOM    NaN     NaN
# 2  data\Bleeding\DICOM\10036.dcm  Bleeding  train  DICOM    NaN     NaN
# 3  data\Bleeding\DICOM\10039.dcm  Bleeding  train  DICOM    NaN     NaN
# 4  data\Bleeding\DICOM\10045.dcm  Bleeding  train  DICOM    NaN     NaN
#
#   study_id series_id instance  slope  intercept    wl     ww
# 0     None      None     None    1.0        0.0  40.0  120.0
# 1     None      None     None    1.0        0.0  40.0  120.0
# 2     None      None     None    1.0    -1024.0  35.0   80.0
# 3     None      None     None    1.0    -1024.0  40.0  100.0
# 4     None      None     None    1.0    -1024.0  50.0  100.0

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16323 entries, 0 to 16322
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  16323 non-null  object
#  1   label       15523 non-null  object
#  2   subset      16323 non-null  object
#  3   format      16323 non-null  object
#  4   width       9473 non-null   float64
#  5   height      9473 non-null   float64
#  6   study_id    0 non-null      object
#  7   series_id   0 non-null      object
#  8   instance    0 non-null      object
#  9   slope       6850 non-null   float64
#  10  intercept   6850 non-null   float64
#  11  wl          6850 non-null   float64
#  12  ww          6850 non-null   float64
# dtypes: float64(6), object(7)
# memory usage: 1.6+ MB
# image_path        0
# label           800
# subset            0
# format            0
# width          6850
# height         6850
# study_id      16323
# series_id     16323
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df[df['subset'] == 'train'], x='label', palette='viridis')
plt.title("Distribución de clases (train)")
plt.show()
# Out:
# C:\Users\mikae\AppData\Local\Temp\ipykernel_9180\4152429879.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['subset'] == 'train'], x='label', palette='viridis')

# %%
sns.countplot(data=df, x='format', hue='subset', palette='magma')
plt.title("Cantidad de imágenes por formato y subset")
plt.show()
